# %% [markdown]
# ### 🤖 LLM and AI Agent Development Courses
# **✨ All courses available for just ₹399 INR / $9.99 USD ✨**
#
# | Course | Description | Enroll |
# |--------|-------------|---------|
# | **🎯 Master OpenAI Agent Builder** | Build and deploy AI agents visually using OpenAI Agent Builder, ChatKit, RAG, Chatbot, AI Assistant with MCP, AWS, RDS MySQL | [Enroll Now](https://kgptalkie.com/agent-builder) |
# | **🔥 MCP Mastery** | Build MCP servers & clients with Python, Streamlit, ChromaDB, LangChain, LangGraph agents, and Ollama integrations | [Enroll Now](https://kgptalkie.com/mcp) |
# | **📊 Private Agentic RAG with LangChain** | Step-by-Step Guide to RAG with LangChain v1, LangGraph, and Ollama (Qwen3, Gemma3, DeepSeek-R1, LLAMA, FAISS) | [Enroll Now](https://kgptalkie.com/agentic-rag) |
# | **🔧 Master LangGraph and LangChain** | Agentic RAG and Chatbot, AI Agent with LangChain v1, Qwen3, Gemma3, DeepSeek-R1, LLAMA 3.2, FAISS Vector Database | [Enroll Now](https://kgptalkie.com/langgraph) |
# | **⚡ Master Langchain and Ollama** | Master Langchain v1, Local LLM Projects with Ollama, Qwen3, Gemma3, DeepSeek-R1, LLAMA 3.2, Complete Integration Guide | [Enroll Now](https://kgptalkie.com/langchain) |
# | **🔬 Fine Tuning LLM** | Learn transformer architecture fundamentals and fine-tune LLMs with custom datasets | [Enroll Now](https://kgptalkie.com/fine-tuning-llm) |
#
# ---
#
# ### 🌐 Join the Community & Stay Connected
#
# - 🔗 **Join the Discord Community:** https://discord.gg/RFjwbkNa
# - 📺 **Subscribe on YouTube (63K+ learners):** http://www.youtube.com/@KGPTalkie
#
# ---

# %% [markdown]
# ## PDF Document Loaders
# - Load various kind of documents from the web and local files.
# - Apply LLM to the documents for summarization and question answering.

# %% [markdown]
# ### Project 1: Question Answering from PDF Document
# - We will load the document from the local file and apply LLM to answer the questions.
# - Lets use research paper published on the missuse of the health supplements for workout.

# %% [markdown]
# rag-dataset: git@github.com:laxmimerit/rag-dataset.git
#
# ```bash
# git clone git@github.com:laxmimerit/rag-dataset.git
# ```

# %%
# !git clone git@github.com:laxmimerit/rag-dataset.git
# !git clone https://github.com/laxmimerit/rag-dataset.git
# !pip install pymupdf tiktoken
# Out:
# fatal: destination path 'rag-dataset' already exists and is not an empty directory.

# %%
from dotenv import load_dotenv

load_dotenv('./../.env')
# Out:
# False

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader("rag-dataset/health supplements/1. dietary supplements - for whom.pdf")

docs = loader.load()

# %%
len(docs)
# Out:
# 17

# %%
# docs[0].metadata
# print(docs[0].page_content)

# %%
### Read the list of PDFs in the dir
import os

pdfs = []
for root, dirs, files in os.walk("rag-dataset"):
    # print(root, dirs, files)
    for file in files:
        if file.endswith(".pdf"):
            pdfs.append(os.path.join(root, file))

# %%
docs = []
for pdf in pdfs:
    loader = PyMuPDFLoader(pdf)
    temp = loader.load()
    docs.extend(temp)

    # print(temp)
    # break

# %%
len(docs)
# Out:
# 64

# %%
def format_docs(docs):
    return "\n\n".join([x.page_content for x in docs])


context = format_docs(docs)

# %%
docs[0]
# Out:
# Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'rag-dataset\\gym supplements\\1. Analysis of Actual Fitness Supplement.pdf', 'file_path': 'rag-dataset\\gym supplements\\1. Analysis of Actual Fitness Supplement.pdf', 'total_pages': 15, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-10-21T11:38:50+00:00', 'trapped': '', 'modDate': 'D:20241021113850Z', 'creationDate': '', 'page': 0}, page_content='Citation: Espeño, P.R.; Ong, A.K.S.;\nGerman, J.D.; Gumasing, M.J.J.; Casas,\nE.S. Analysis of Actual Fitness\nSupplement Consumption among\nHealth and Fitness Enthusiasts. Foods\n2024, 13, 1424. https://doi.org/\n10.3390/foods13091424\nAcademic Editors: Ilija Djekic\nand Nada Smigic\nReceived: 30 March 2024\nRevised: 15 April 2024\nAccepted: 18 April 2024\nPublished: 6 May 2024\nCopyright: © 2024 by the authors.\nLicensee MDPI, Basel, Switzerland.\nThis article is an open access article\ndistributed\nunder\nthe\nterms\nand\nconditions of the Creative Commons\nAttribution (CC BY) license (https://\ncreativecommons.org/licenses/by/\n4.0/).\nfoods\nArticle\nAnalysis of Actual Fitness Supplement Consumption among\nHealth and Fitness Enthusiasts\nPaolo Renzo Espeño 1, Ardvin Kester S. Ong 1,2,*\n, Josephine D. German 1\n, Ma. Janice J. Gumasing 3\nand Ethan S. Casas 1\n1\nSchool of Industrial Engineering and Engineering Management, Mapúa University, 658 Muralla St.,\nIntramuros, Manila 1002, Philippines\n2\nE.T. Yuchengo School of Business, Mapúa University, 1191 Pablo Ocampo Sr. Ext., Makati 1204, Philippines\n3\nDepartment of Industrial and Systems Engineering, Gokongwei College of Engineering,\nDe La Salle University, 2401 Taft Ave., Manila 1007, Philippines\n*\nCorrespondence: aksong@mapua.edu.ph; Tel.: +63-(2)8247-5000 (ext. 6202)\nAbstract: With the rising popularity of fitness supplements, understanding the factors driving their\nconsumption behaviors is crucial. This study investigated the actual consumption of fitness supple-\nments utilizing the Theory of Planned Behavior (TPB), Health Belief Model (HBM), and the Theory\nof Effort Minimization in Physical Activity (TEMPA) frameworks. The TPB provided insights into\nhow attitudes, subjective norms, and perceived behavioral control influence individuals’ intentions\nto consume fitness supplements. Additionally, the HBM sheds light on perceived effectiveness,\nbenefits, barriers, and health motivation related to supplement consumption. Integrating the TEMPA\nframework further investigated the role of effort minimization in physical activity contexts. Through\nan online questionnaire, data were collected from a sample of 250 fitness supplement-consuming\nrespondents. SEM analysis revealed significant associations between behavioral intentions and\nattitudes, perceived behavioral control, health motivation, and controlled precursors. However, it\nwas seen that subjective norms, perceived effectiveness, perceived benefits, and automatic precursors\nwere deemed insignificant. The findings contribute to a comprehensive understanding of the factors\nshaping actual consumption behaviors, offering valuable implications for marketers, health profes-\nsionals, and policymakers seeking to promote informed and responsible supplement use among\nhealth and fitness enthusiasts.\nKeywords: fitness supplements; health belief model; theory of effort of minimization; theory of\nplanned behavior; structural equation modelling\n1. Introduction\nSupplementary drinks or fitness supplements are commonly used to enhance an\nindividual’s performance in various sports and health settings, catering to both competitive\nand non-competitive athletes [1]. One widely known supplement for athletes and fitness\nenthusiasts is protein supplements like protein shakes. Others may be whey protein,\ncaffeine, and creatine, to name a few. These supplements play a crucial role in helping\nindividuals increase muscle mass, recover faste ...

# %%
# print(context)

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4o-mini")

# %%
encoding.encode("congratulations"), encoding.encode("rqsqeft")
# Out:
# ([542, 111291, 14571], [81, 31847, 80, 5276])

# %%
len(encoding.encode(docs[0].page_content))
# Out:
# 968

# %%
len(encoding.encode(context))
# Out:
# 58181

# %%
969*64
# Out:
# 62016

# %%
### Question Answering using LLM
from langchain_ollama import ChatOllama

from langchain_core.prompts import (SystemMessagePromptTemplate, HumanMessagePromptTemplate,
                                    ChatPromptTemplate)



from langchain_core.output_parsers import StrOutputParser

base_url = "http://localhost:11434"
# model = 'qwen3'
model = 'llama3.2'

llm = ChatOllama(base_url=base_url, model=model)

# %%
system = SystemMessagePromptTemplate.from_template("""You are helpful AI assistant who answer user question based on the provided context. 
                                                    Do not answer in more than {words} words""")

prompt = """Answer user question based on the provided context ONLY! If you do not know the answer, just say "I don't know".
            ### Context:
            {context}

            ### Question:
            {question}

            ### Answer:"""

prompt = HumanMessagePromptTemplate.from_template(prompt)

messages = [system, prompt]
template = ChatPromptTemplate(messages)

# template
# template.invoke({'context': context, 'question': "How to gain muscle mass?", 'words': 50})

qna_chain = template | llm | StrOutputParser()

# %%
qna_chain
# Out:
# ChatPromptTemplate(input_variables=['context', 'question', 'words'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['words'], input_types={}, partial_variables={}, template='You are helpful AI assistant who answer user question based on the provided context. \n                                                    Do not answer in more than {words} words'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Answer user question based on the provided context ONLY! If you do not know the answer, just say "I don\'t know".\n            ### Context:\n            {context}\n\n            ### Question:\n            {question}\n\n            ### Answer:'), additional_kwargs={})])
# | ChatOllama(output_version=None, model='llama3.2', base_url='http://localhost:11434')
# | StrOutputParser()

# %%
response = qna_chain.invoke({'context': context, 'question': "How to gain muscle mass?", 'words': 50})
print(response)
# Out:
# It seems like you provided a snippet of a text and then asked "How to gain muscle mass?" which is unrelated to the content of the original text. The original text was discussing the adverse effects of dietary supplements, botanicals, and herbal supplements.
#
# If you'd like, I can provide an answer based on the context of the original text:
#
# To address the question in a general sense, gaining muscle mass requires a combination of proper nutrition, consistent training, and adequate rest. However, this is not related to the topic of adverse effects of dietary supplements and botanicals discussed in the original text.
#
# If you'd like to discuss the topic of herbal supplements or dietary supplements, I can provide more information on the potential risks and interactions associated with their use.

# %%
response = qna_chain.invoke({'context': context, 'question': "How to reduce the weight?", 'words': 50})
print(response)
# Out:
# The answer to "How to reduce the weight?" is not explicitly provided in the text, but some potential methods and supplements that may be mentioned include:
#
# 1. Using a multi-ingredient dietary supplement like OxyELITE Pro (although this has been associated with liver injury)
# 2. Taking botanical supplements such as black cohosh, kava kava, saw palmetto, or ginseng
# 3. Engaging in bodybuilding and using anabolic steroids (although these are modified variants of androgens designed to increase muscle mass and can have adverse effects)
#
# However, it's worth noting that the text also mentions the importance of consulting with a healthcare provider before taking any supplement, as many botanicals can interact with prescription medications or have adverse effects.
#
# To answer "How to reduce the weight?" in a more general sense:
#
# 1. Engage in regular physical activity and exercise
# 2. Maintain a healthy diet and calorie intake
# 3. Get enough sleep and manage stress levels
# 4. Consider consulting with a registered dietitian or healthcare provider for personalized advice
#
# Please consult reputable sources of health information, such as the National Institutes of Health (NIH) or the Academy of Nutrition and Dietetics, for evidence-based guidance on weight loss and nutrition.

# %%
response = qna_chain.invoke({'context': context, 'question': "How to do weight loss?", 'words': 50})
print(response)
# Out:
# The answer is not provided as the prompt was interrupted and the original question about how to do weight loss was cut off. However, I can provide general information on weight loss.
#
# Weight loss can be achieved through a combination of healthy diet, regular exercise, and lifestyle changes. Here are some evidence-based tips:
#
# 1. **Eat a balanced diet**: Focus on whole, unprocessed foods like vegetables, fruits, whole grains, lean proteins, and healthy fats.
# 2. **Keep track of your calorie intake**: Use a food diary or an app to monitor your daily calorie consumption and make adjustments as needed.
# 3. **Incorporate physical activity**: Aim for at least 150 minutes of moderate-intensity exercise or 75 minutes of vigorous-intensity exercise per week.
# 4. **Stay hydrated**: Drink plenty of water throughout the day to help control hunger and boost metabolism.
# 5. **Get enough sleep**: Aim for 7-9 hours of sleep per night to support weight regulation and overall health.
# 6. **Manage stress**: Engage in stress-reducing activities like meditation, yoga, or deep breathing exercises.
#
# Remember, losing weight too quickly is not healthy and is unlikely to be sustainable. Aim for a slow and steady weight loss of 1-2 pounds per week.
#
# (And, just to reiterate, the original text discussed adverse effects of dietary supplements, including some examples listed in Table 1.)

# %%
response = qna_chain.invoke({'context': context, 'question': "How many planets are there outside of our solar system?", 'words': 50})
print(response)
# Out:
# It seems like you've provided a question and an answer, but the answer doesn't relate to the topic of the text. The text discusses adverse effects caused by dietary supplements, botanicals, and their interactions with medications.
#
# To respond to your initial request, I'll provide some general information on the topic. However, please note that the original question about the number of planets outside our solar system is unrelated to the provided text.
#
# There are thousands of exoplanets discovered so far outside our solar system. According to NASA's Exoplanet Archive, there are over 4,100 confirmed exoplanets and thousands more candidates waiting for confirmation. However, it's difficult to give an exact number, as new discoveries are constantly being made, and the definition of a "planet" can be nuanced.
#
# Regarding dietary supplements and botanicals, the text discusses various adverse effects associated with their use, including liver toxicity, seizures, bleeding, and interactions with medications. It also highlights the importance of monitoring these substances for potential toxicities and herb-drug interactions.

# %% [markdown]
# ### Project 2: PDF Document Summarization

# %%
system = SystemMessagePromptTemplate.from_template("""You are helpful AI assistant who works as document summarizer. 
                                                   You must not hallucinate or provide any false information.""")

prompt = """Summarize the given context in {words}.
            ### Context:
            {context}

            ### Summary:"""

prompt = HumanMessagePromptTemplate.from_template(prompt)

messages = [system, prompt]
template = ChatPromptTemplate(messages)

summary_chain = template | llm | StrOutputParser()

# %%
summary_chain
# Out:
# ChatPromptTemplate(input_variables=['context', 'words'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are helpful AI assistant who works as document summarizer. \n                                                   You must not hallucinate or provide any false information.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'words'], input_types={}, partial_variables={}, template='Summarize the given context in {words}.\n            ### Context:\n            {context}\n\n            ### Summary:'), additional_kwargs={})])
# | ChatOllama(output_version=None, model='llama3.2', base_url='http://localhost:11434')
# | StrOutputParser()

# %%
response = summary_chain.invoke({'context': context, 'words': 50})
print(response)
# Out:
# The article discusses the potential risks and adverse effects of various dietary supplements, including botanicals, anti-obesity drugs, anabolic steroids, and untested or undeclared compounds. The authors highlight the importance of regulation and monitoring of these products to ensure public safety.
#
# Some specific examples of adverse effects include:
#
# * Liver toxicity from botanicals such as black cohosh, kava kava, and saw palmetto
# * Cholestatic symptoms from kava kava and echinacea
# * Seizures and cardiovascular problems from yohimbine
# * Exacerbated hemochromatosis from milk thistle
# * Transient ischemia attack from ginseng
# * Bradycardia from black cohosh
# * Excessive bleeding from garlic and ginkgo biloba
#
# The article also discusses the importance of herb-drug interactions, including:
#
# * Activation of the pregnane-X receptor (PXR) and the aryl hydrocarbon receptor (AhR)
# * Induction or suppression of metabolizing enzymes, which can affect the pharmacokinetics of drugs
# * Potential contraindications for health care providers
#
# Overall, the article emphasizes the need for caution and vigilance when using dietary supplements, particularly those that are not regulated by the FDA.

# %%
response = summary_chain.invoke({'context': context, 'words': 500})
print(response)
# Out:
# The article discusses the potential adverse effects of botanical and herbal supplements, including liver toxicity, interactions with medications, and other health problems. The authors review case reports and studies to highlight the risks associated with these products.
#
# **Liver Toxicity**
#
# * Black cohosh (Cimicifuga racemosa) has been linked to jaundice and liver failure in menopausal women.
# * Kava kava has been reported to cause liver toxicity, with mechanisms including depletion of glutathione and inhibition of cyclooxygenases.
# * Saw palmetto use has been associated with cholestatic hepatitis.
#
# **Interactions with Medications**
#
# * Botanicals can activate the pregnane-X receptor (PXR) and the aryl hydrocarbon receptor (AhR), leading to interactions with medications.
# * Examples include herbal teas that inhibit platelet aggregation, such as gingko biloba.
#
# **Other Health Problems**
#
# * Yohimbine use has been linked to seizures, tachycardia, and hypertension.
# * Milk thistle use has been implicated in exacerbated hemochromatosis (iron overload).
# * Ginseng use has been associated with transient ischemia attack.
# * Black cohosh has been deemed "probably responsible" for observed bradycardia.
#
# **Mechanisms**
#
# * The mechanisms underlying the adverse effects of botanicals are not always understood, but may involve activation of the pregnane-X receptor (PXR) and the aryl hydrocarbon receptor (AhR), as well as mitochondrial dysfunction and oxidative stress.
# * The authors highlight the need for further research to understand the toxic mechanisms of botanicals.
#
# **Conclusion**
#
# The article emphasizes the importance of caution when using botanical and herbal supplements, as their potential adverse effects can be significant. Patients should be advised to consult with healthcare providers before taking these products, particularly if they are also taking medications or have underlying health conditions.

# %% [markdown]
# ### Project 3: Report Generation from PDF Document

# %% [markdown]
# Streamlit Tutorial: https://www.youtube.com/watch?v=hff2tHUzxJM&list=PLc2rvfiptPSSpZ99EnJbH5LjTJ_nOoSWW

# %%
response = qna_chain.invoke({'context': context, 
                             'question': "Provide a detailed report from the provided context. Write answer in Markdown.", 
                             'words': 2000})
print(response)
# Out:
# **Detailed Report on Adverse Effects and Herb-Drug Interactions of Botanical Supplements**
#
# The use of botanical supplements has gained popularity due to their natural origin and perceived health benefits. However, these substances can also cause adverse effects, interact with other medications, and lead to severe liver injuries.
#
# **Commonly Used Botanical Supplements and Their Associated Risks**
#
# 1. **Black Cohosh (Cimicifuga racemosa)**: associated with jaundice and liver failure in menopausal women. Pathological oxidative stress has been observed in biopsy samples.
# 2. **Kava Kava**: liver toxicity, sometimes requiring transplants. Mechanisms include depletion of glutathione and inhibition of cyclooxygenases (mitochondrial dysfunction).
# 3. **Saw Palmetto**: cholestatic hepatitis, alterations in bile secretion linked to pancreatitis.
# 4. **Echinacea**: acute liver failure with unknown mechanism.
# 5. **Valerian**: jaundice reversed by steroid administration.
# 6. **Yohimbine**: sympathomimetic properties, led to seizure, tachycardia, and hypertension in a bodybuilder.
# 7. **Milk Thistle**: exacerbated hemochromatosis (iron overload) in a genetically predisposed individual.
# 8. **Ginseng**: transient ischemia attack with unknown mechanism.
# 9. **Black Cohosh**: "probably responsible" for observed bradycardia, possibly through activation of serotonin receptors.
# 10. **Garlic and Ginkgo Biloba**: excessive bleeding due to inhibition of platelet aggregation.
#
# **Herb-Drug Interactions**
#
# 1. Activation of the pregnane-X receptor (PXR) and the aryl hydrocarbon receptor (AhR) as a common mechanism among several botanicals.
# 2. Induction or suppression of relevant metabolizing enzymes can affect the pharmacokinetics of drugs, warranting contraindications by healthcare providers.
#
# **Mechanisms of Adverse Effects**
#
# 1. Mitochondrial dysfunction and oxidative stress
# 2. Alteration of bile acid homeostasis
# 3. Inhibition of cyclooxygenases (mitochondrial dysfunction)
# 4. Depletion of glutathione
#
# **Importance of Safe Botanical Use**
#
# 1. Patients may not report herbal supplement use to primary care physicians, posing a risk.
# 2. Bioactive constituents of botanicals can have acute adverse effects requiring hospitalization.
# 3. Contraindications and caution should be exercised when using botanical supplements with other medications.
#
# In conclusion, while botanical supplements offer potential health benefits, they can also cause adverse effects, interact with other medications, and lead to severe liver injuries. It is essential for patients and healthcare providers to be aware of the risks associated with these substances and take necessary precautions to ensure safe use.
